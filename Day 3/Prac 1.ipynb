# %%
total_neurons = 8
dropout_rate = 0.25

active_neurons = (total_neurons * (1 - dropout_rate))
print(f"Active Neurons after Dropout {active_neurons}")
# Out:
# Active Neurons after Dropout 6.0

# %%
import numpy as np

# %%
X = np.array([1, 3, 5, 7, 9])

mean = X.mean()
var = X.var()

print(f"Mean : {mean}")
print(f"Variance : {var}")
# Out:
# Mean : 5.0
# Variance : 8.0
