# %%
xt = 2
prev_state = 1
wx = 0.5
wh = 0.8

bais = 0.1

# %%
input_contrib = xt * wx
input_contrib
# Out:
# 1.0

# %%
hidden_contrib = prev_state * wh
hidden_contrib
# Out:
# 0.8

# %%
ht = input_contrib + hidden_contrib + bais
ht
# Out:
# 1.9000000000000001
