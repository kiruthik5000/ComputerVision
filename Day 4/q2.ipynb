# %%
f_gate = 0.7 # how much memory to retain
ip_gate = 0.6 # how much new information came
cm = 0.5 # possible new information
prev_state = 1 # memory state from prev time stamp

# %%
ct = f_gate * prev_state + ip_gate * cm
ct # new cell state
# Out:
# 1.0
