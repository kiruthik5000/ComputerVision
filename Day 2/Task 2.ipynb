# %%
import numpy as np

# %%
def get_loss(y_true: np.float32, y_pred: np.float32) -> np.float32:
    return np.square(y_true - y_pred)

def backpropagation(y_true: np.float32, y_pred: np.float32) -> np.float32:
    return -2 * (y_true - y_pred)

# %% [markdown]
# # Task 1

# %%
y_true, y_pred = 1, 0.6

L = get_loss(y_true, y_pred)
dy_dx = backpropagation(y_true, y_pred)

print(f"dL/dŷ = {dy_dx}")
print(f"")
# Out:
# dL/dŷ = -0.8

# %% [markdown]
# # Task 2

# %%
w, x = 0.5, 2

dl_dw = dy_dx * x

print(f"dy/dw = {x}")
print(f"dL/dw = {dl_dw}")
# Out:
# dy/dw = 2
# dL/dw = -1.6
