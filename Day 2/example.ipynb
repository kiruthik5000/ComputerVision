# %%
def gradient_descent(w: float, n: float, dw: float) -> float:
    return w - (n * dw)

# %%
initial_w = 0.5
lr = 0.5
dw = 0.2


updated_w = gradient_descent(initial_w, lr, dw)
print(updated_w)
# Out:
# 0.4

# %%
p_val = 0.6
actual_val = 1

L = (actual_val - p_val) ** 2
f"{L:.4f}"
# Out:
# '0.1600'
